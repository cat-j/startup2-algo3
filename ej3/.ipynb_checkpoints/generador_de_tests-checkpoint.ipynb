# %% [markdown]
# # Lets Create Some Random Graphs

# %%
import pandas as pd
import sys
sys.path.append('/usr/local/lib/python2.7/dist-packages')
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import random

# %%
def generarGrafoPesosNormales(f, c, mu=5, sigma=1, p_arista=0.5):
    assert(f<=c)

    grafo = []
    verticesUsados = []
    aristasUsadas = []

    # Genera un grafo minimal con respecto a que cualquier cliente
    # sea alcanzable desde al menos una fábrica.

    for cliente in range(f+1, f+c+1):
        # Se asegura de que cada cliente sea adyacente a una fábrica
        # o a otro cliente tal que hay un camino entre él y una fábrica.
        vecino = np.random.choice([i for i in range(1,f+1)] + verticesUsados)
        verticesUsados.append(cliente)
        l, r = min(cliente, vecino), max(cliente, vecino)
        grafo.append([ l, r, int(max(np.random.normal(mu, sigma), 0)) ])
        aristasUsadas.append((l,r))

    # Agrega más aristas con probabilidad p_arista.
    # Cada una es independiente.

    for i in range(1, f+c+1):
        for j in range(i+1, f+c+1):
            if not((i,j) in aristasUsadas):
                p = np.random.uniform()
                if p <= p_arista:
                    grafo.append([ i, j, int(max(np.random.normal(mu, sigma), 0)) ])

    grafoStr = [ " ".join( str(k) for k in e ) for e in grafo ]

    return grafoStr

def generarEntradaPropClientes(n, mu=5, sigma=1, p_arista=0.5, archivo="output"):
    # Genera un caso de test con 32 grafos de n nodos. Los pesos están distribuidos
    # normalmente según los parámetros especificados.
    minimo = n // 2 if n%2 == 0 else n // 2 + 1

    with open(archivo, 'w') as entrada:
        for k in range(minimo,n):    
            for i in range(30):
                grafo = generarGrafoPesosNormales(n-k, k, mu, sigma, p_arista)
                entrada.write(str(n-k) + " " + str(k) + " " + str(len(grafo)) + '\n')
                for j in grafo:
                    entrada.write(j + '\n')

        entrada.write("0\n")
        
def generarEntradaCantidadesFijas(f, c, mu=5, sigma=1, archivo="output"):
    # Genera un caso de test con 32 grafos de n nodos. Los pesos están distribuidos
    # normalmente según los parámetros especificados.
    with open(archivo, 'w') as entrada:
        for p in np.arange(0.0, 1.1, 0.1):
            for i in range(50):
                grafo = generarGrafoPesosNormales(f, c, mu, sigma, p)
                entrada.write(str(f) + " " + str(c) + " " + str(len(grafo)) + '\n')
                for j in grafo:
                    entrada.write(j + '\n')
        entrada.write("0\n")

# %%
generarEntradaPropClientes(50, 20, 5, 0.5, "tests/proporcionClientes.test-in")

# %%
generarEntradaCantidadesFijas(20, 30, 20, 5, "tests/densidadCreciente.test-in")

# %% [markdown]
# # Corremos el experimento

# %%
! make expe

# %%
dfClientes.groupby("Cantidad de clientes").mean()

# for key, value in results.items():
#     results[key] = value.groupby("Cantidad de fabricas").mean()
# # dfNormal = dfNormal.groupby("Cantidad de Nodos").mean()
# results["dfNormal_1.0"]
# Out:
#                       Cantidad de fabricas  Cantidad de rutas  \
# Cantidad de clientes
# 25                                      25         626.566667
# 26                                      24         627.766667
# 27                                      23         627.933333
# 28                                      22         625.700000
# 29                                      21         628.266667
# 30                                      20         623.033333
# 31                                      19         623.800000
# 32                                      18         625.066667
# 33                                      17         628.233333
# 34                                      16         632.833333
# 35                                      15         632.100000
# 36                                      14         630.700000
# 37                                      13         633.433333
# 38                                      12         628.166667
# 39                                      11         634.200000
# 40                                      10         632.833333
# 41                                       9         633.733333
# 42                                       8         639.966667
# 43                                       7         632.533333
# 44                                       6         640.000000
# 45                                       5         636.100000
# 46                                       4         630.266667
# 47                                       3         636.666667
# 48                                       2         636.466667
# 49                                       1         631.633333
#
#                       Tiempo de ejecucion  Tamaño de la solucion
# Cantidad de clientes
# 25                               0.000190                     25
# 26                               0.000171                     26
# 27                               0.000215                     27
# 28                               0.000160                     28
# 29                               0.000165                     29
# 30                               0.000156                     30
# 31                               0.000162                     31
# 32                               0.000198                     32
# 33                               0.000156                     33
# 34                               0.000161                     34
# 35                               0.000159                     35
# 36                               0.000161                     36
# 37                               0.000163                     37
# 38                               0.000157                     38
# 39                               0.000169                     39
# 40                               0.000167                     40
# 41                               0.000170                     41
# 42                               0.000164                     42
# 43                               0.000157                     43
# 44                               0.000159                     44
# 45                               0.000158                     45
# 46                               0.000154                     46
# 47                               0.000156                     47
# 48                               0.000153                     48
# 49                               0.000143                     49
#
# [25 rows x 4 columns]

# %%
ax = dfClientes.plot(x="Cantidad de clientes", y="Tamaño de la solucion")
ax.set_ylabel("Tamaño de la solución")
plt.show()

# %%
## Experimento 2
dfDensidadCreciente = pd.read_csv("experimentacion/densidadCreciente.stderr", delimiter=";")
dfDensidadCreciente.groupby("Cantidad de rutas").mean()
# Out:
#                    Cantidad de fabricas  Cantidad de clientes  \
# Cantidad de rutas
# 30                                   20                    30
# 121                                  20                    30
# 123                                  20                    30
# 126                                  20                    30
# 131                                  20                    30
# 134                                  20                    30
# 135                                  20                    30
# 136                                  20                    30
# 140                                  20                    30
# 141                                  20                    30
# 143                                  20                    30
# 145                                  20                    30
# 146                                  20                    30
# 147                                  20                    30
# 148                                  20                    30
# 149                                  20                    30
# 150                                  20                    30
# 151                                  20                    30
# 152                                  20                    30
# 153                                  20                    30
# 154                                  20                    30
# 155                                  20                    30
# 156                                  20                    30
# 158                                  20                    30
# 159                                  20                    30
# 161                                  20                    30
# 163                                  20                    30
# 166                                  20                    30
# 175                                  20                    30
# 248                                  20                    30
# 249                                  20                    30
# 250                                  20                    30
# 252                                  20                    30
# 253                                  20                    30
# 254                                  20                    30
# 255                                  20                    30
# 256                                  20                    30
# 257                                  20                    30
# 258                                  20                    30
# 259                                  20                    30
# 261                                  20                    30
# 262                                  20                    30
# 263                                  20                    30
# 264                                  20                    30
# 266                                  20                    30
# 267                                  20                    30
# 268                                  20                    30
# 269                                  20                    30
# 270                                  20                    30
# 271                                  20                    30
# 272                                  20                    30
# 273                                  20                    30
# 275                                  20                    30
# 276                                  20                    30
# 277                                  20                    30
# 279                                  20                    30
# 280                                  20                    30
# 281                                  20                    30
# 282                                  20                    30
# 284                                  20                    30
#                                     ...                   ...
#
#                    Tiempo de ejecucion  Tamaño de la solucion
# Cantidad de rutas
# 30                            0.000014                     30
# 121                           0.000037                     30
# 123                           0.000034                     30
# 126                           0.000039                     30
# 131                           0.000038                     30
# 134                           0.000044                     30
# 135                           0.000039                     30
# 136                           0.000041                     30
# 140                           0.000040                     30
# 141                           0.000040                     30
# 143                           0.000040                     30
# 145                           0.000047                     30
# 146                           0.000040                     30
# 147                           0.000041                     30
# 148                           0.000042                     30
# 149                           0.000043                     30
# 150                           0.000041                     30
# 151                           0.000043                     30
# 152                           0.000056                     30
# 153                           0.000042                     30
# 154                           0.000047                     30
# 155                           0.000045                     30
# 156                           0.000044                     30
# 158                           0.000049                     30
# 159                           0.000044                     30
# 161                           0.000044                     30
# 163                           0.000046                     30
# 166                           0.000047                     30
# 175                           0.000050                     30
# 248                           0.000066                     30
# 249                           0.000066                     30
# 250                           0.000079                     30
# 252                           0.000066                     30
# 253                           0.000068                     30
# 254                           0.000065                     30
# 255                           0.000066                     30
# 256                           0.000067                     30
# 257                           0.000069                     30
# 258                           0.000070                     30
# 259                           0.000065                     30
# 261                           0.000071                     30
# 262                           0.000065                     30
# 263                           0.000074                     30
# 264                           0.000071                     30
# 266                           0.000071                     30
# 267                           0.000068                     30
# 268                           0.000072                     30
# 269                           0.000073                     30
# 270                           0.000069                     30
# 271                           0.000070                     30
# 272                           0.000072                     30
# 273                           0.000070                     30
# 275                           0.000070                     30
# 276                           0.000073                     30
# 277                           0.000075                     30
# 279                           0.000073                     30
# 280                           0.000073                     30
# 281                           0.000092                     30
# 282                           0.000074                     30
# 284                           0.000073                     30
#                                    ...                    ...
#
# [293 rows x 4 columns]

# %%
ax = dfDensidadCreciente.plot(logy=False, x="Cantidad de rutas", y="Tiempo de ejecucion")
plt.show()

# %%
dfComp = pd.DataFrame()
dfComp['Cantidad de Nodos'] = results["dfNormal_1.0"].index.values
dfComp['Complejidad n**2'] = [100 + random.normalvariate(n**2,2) for n in results["dfNormal_0.0"].index.values]
dfComp['Complejidad n'] = [100 + random.normalvariate(n,0.3) for n in results["dfNormal_0.0"].index.values]

dfComp['Tiempo en segundos de completos'] =  results["dfNormal_1.0"]['Tiempo generando Mst']
dfComp['Tiempo en segundos de arboles'] =  results["dfNormal_0.0"]['Tiempo generando Mst']
plt.clf()
correlation = dfComp.corr()
correlation
# Out:
#                                  Cantidad de Nodos  Complejidad n**2  \
# Cantidad de Nodos                         1.000000          0.979568
# Complejidad n**2                          0.979568          1.000000
# Complejidad n                             0.999441          0.978017
# Tiempo en segundos de completos           0.978757          0.998466
# Tiempo en segundos de arboles             0.998395          0.987130
#
#                                  Complejidad n  \
# Cantidad de Nodos                     0.999441
# Complejidad n**2                      0.978017
# Complejidad n                         1.000000
# Tiempo en segundos de completos       0.978185
# Tiempo en segundos de arboles         0.998131
#
#                                  Tiempo en segundos de completos  \
# Cantidad de Nodos                                       0.978757
# Complejidad n**2                                        0.998466
# Complejidad n                                           0.978185
# Tiempo en segundos de completos                         1.000000
# Tiempo en segundos de arboles                           0.978272
#
#                                  Tiempo en segundos de arboles
# Cantidad de Nodos                                     0.998395
# Complejidad n**2                                      0.987130
# Complejidad n                                         0.998131
# Tiempo en segundos de completos                       0.978272
# Tiempo en segundos de arboles                         1.000000

# %%
sns.jointplot(dfComp['Complejidad n**2'], dfComp['Tiempo en segundos de completos'], kind="reg")
sns.jointplot(dfComp['Complejidad n'], dfComp['Tiempo en segundos de arboles'], kind="reg")


plt.show()

# %%
dfRoot = pd.DataFrame({'Arboles': results["dfNormal_0.0"]['Tiempo calculando raiz'],
                  'P = 0.25': results["dfNormal_0.25"]['Tiempo calculando raiz'],
                  'P = 0.5': results["dfNormal_0.5"]['Tiempo calculando raiz'],
                  'P = 0.75': results["dfNormal_0.75"]['Tiempo calculando raiz'],
                  'Completos': results["dfNormal_1.0"]['Tiempo calculando raiz']})

ax = dfRoot.plot(logy=False)
ax.set_ylabel("Tiempos de ejecución en Segundos")
ax.set_xlabel("Cantidad de nodos")

plt.title("Tiempos para encontrar el MST")
plt.show()

# %%
dfComp = pd.DataFrame()
dfComp['Cantidad de Nodos'] = results["dfNormal_1.0"].index.values
dfComp['Complejidad n**2'] = [100 + random.normalvariate(n**2,2) for n in results["dfNormal_0.0"].index.values]
dfComp['Complejidad n'] = [100 + random.normalvariate(n,0.3) for n in results["dfNormal_0.0"].index.values]

dfComp['Tiempo de encontrar raiz en segundos de ex-completos'] =  results["dfNormal_1.0"]['Tiempo calculando raiz']
dfComp['Tiempo de encontrar raiz en segundos de arboles'] =  results["dfNormal_0.0"]['Tiempo calculando raiz']
plt.clf()
correlation = dfComp.corr()
correlation
# Out:
#                                                     Cantidad de Nodos  \
# Cantidad de Nodos                                            1.000000
# Complejidad n**2                                             0.979279
# Complejidad n                                                0.999670
# Tiempo de encontrar raiz en segundos de ex-comp...           0.989304
# Tiempo de encontrar raiz en segundos de arboles              0.998206
#
#                                                     Complejidad n**2  \
# Cantidad de Nodos                                           0.979279
# Complejidad n**2                                            1.000000
# Complejidad n                                               0.978676
# Tiempo de encontrar raiz en segundos de ex-comp...          0.970244
# Tiempo de encontrar raiz en segundos de arboles             0.980576
#
#                                                     Complejidad n  \
# Cantidad de Nodos                                        0.999670
# Complejidad n**2                                         0.978676
# Complejidad n                                            1.000000
# Tiempo de encontrar raiz en segundos de ex-comp...       0.988351
# Tiempo de encontrar raiz en segundos de arboles          0.997675
#
#                                                     Tiempo de encontrar raiz en segundos de ex-completos  \
# Cantidad de Nodos                                                                            0.989304
# Complejidad n**2                                                                             0.970244
# Complejidad n                                                                                0.988351
# Tiempo de encontrar raiz en segundos de ex-comp...                                           1.000000
# Tiempo de encontrar raiz en segundos de arboles                                              0.988109
#
#                                                     Tiempo de encontrar raiz en segundos de arboles
# Cantidad de Nodos                                                                          0.998206
# Complejidad n**2                                                                           0.980576
# Complejidad n                                                                              0.997675
# Tiempo de encontrar raiz en segundos de ex-comp...                                         0.988109
# Tiempo de encontrar raiz en segundos de arboles                                            1.000000

# %%
sns.jointplot(dfComp['Complejidad n'], dfComp['Tiempo de encontrar raiz en segundos de ex-completos'], kind="reg")
sns.jointplot(dfComp['Complejidad n'], dfComp['Tiempo de encontrar raiz en segundos de arboles'], kind="reg")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-b802c8c2d484> in <module>()
# ----> 1 sns.jointplot(dfComp['Complejidad n'], dfComp['Tiempo de encontrar raiz en segundos de ex-completos'], kind="reg")
#       2 sns.jointplot(dfComp['Complejidad n'], dfComp['Tiempo de encontrar raiz en segundos de arboles'], kind="reg")
#       3
#       4 plt.show()
#
# NameError: name 'dfComp' is not defined
